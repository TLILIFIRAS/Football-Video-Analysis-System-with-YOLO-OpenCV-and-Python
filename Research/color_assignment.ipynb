# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np

# %%
image_path="../output_videos/player.jpg" 
image=cv2.imread(image_path)
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
plt.show()

# %% [markdown]
# take the top half of the image that contains the player's color

# %%
top_half_image=  image[0: int(image.shape[0]/2), :]
plt.imshow(top_half_image)
plt.show()

# %% [markdown]
# Cluster the image into two clusters to remove the grass background

# %%
from sklearn.cluster import KMeans

# %%
#reshape the image into a 2D array of pixels 
image_2D = top_half_image.reshape((-1,3))
#prerform kmeans clustering with 2 clusters
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(image_2D)
#get the cluster labels
labels=kmeans.labels_
#reshape the labels into the original image shape
clustered_image = labels.reshape(top_half_image.shape[0], top_half_image.shape[1])
# Display the clustered image
plt.imshow(clustered_image)
plt.show()

# %%
corner_clusters = [clustered_image[0, 0], clustered_image[0, -1], clustered_image[-1, 0], clustered_image[-1, -1]]
non_player_cluster = max(set(corner_clusters), key=corner_clusters.count)
print(non_player_cluster)
# Out:
# 1

# %%
player_cluster = 1-non_player_cluster
print(player_cluster)
# Out:
# 0

# %%
kmeans.cluster_centers_[player_cluster]
# Out:
# array([171.        , 235.38389262, 142.37718121])
